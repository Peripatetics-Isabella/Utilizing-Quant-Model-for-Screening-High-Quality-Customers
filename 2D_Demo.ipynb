# %%
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('grouping.csv').drop('Unnamed: 0',axis = 1)
thres = float(len(df[df.Loan_Default == True]))/len(df)
thres
# Out:
# 0.0893371757925072

# %%
list(df)
# Out:
# ['LoanID',
#  'Terms',
#  'IsInternalRefinance',
#  'IsExternalRefinance',
#  'Gender',
#  'State',
#  'SalaryFrequencyID',
#  'VehicleYear',
#  'Make',
#  'ApplicationTermMonths',
#  'ApplicationDate',
#  'MonthlyPayment',
#  'Month',
#  'Loan_Default',
#  'LoanAmount_Group',
#  'Salary_Group',
#  'SP_Ratio_Group',
#  'V_Age_Group',
#  'Interest',
#  'CO_APP_Default_Status',
#  'Mileage_Group',
#  'Risky_Area',
#  'Age_Group']

# %% [markdown]
#
# A label can be created e.g. using ax.text(). To position the label a nice trick is to use a transform that allows to use axes coordinates for the x position and data coordinates for the y position.
#
# ax.text(1.02, 4.2e4, "42000", .. , transform=ax.get_yaxis_transform())
# Complete code:
#
# import matplotlib.pyplot as plt
# import matplotlib.colors
# import numpy as np
#
# fig = plt.figure()
# ax = fig.add_subplot(111)
# x = [0,1,2,3]
# y = np.array([34,40,38,50])*1e3
# norm = matplotlib.colors.Normalize(30e3, 60e3)
# ax.bar(x,y, color=plt.cm.plasma_r(norm(y)) )
# ax.axhline(4.2e4, color="gray")
# ax.text(1.02, 4.2e4, "42000", va='center', ha="left", bbox=dict(facecolor="w",alpha=0.5),
#         transform=ax.get_yaxis_transform())
# plt.show()

# %%
table=pd.crosstab(df.Gender,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
#fig = plt.figure()
#ax = fig.add_subplot(111)
plt.title('Stacked Bar Chart of Gender vs Loan Default Status')
plt.xlabel('Gender')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="red")
plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('gender_vs_default_stack')

# %%
table=pd.crosstab(df.SP_Ratio_Group,df.LoanAmount_Group)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of SP Ratio Level vs Loan Amount Level')
plt.xlabel('SP Ratio level')
plt.ylabel('Proportion of Loans')
plt.legend(fancybox=True, shadow=True,title = 'Loan_Amount_Level', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Ratio_vs_loanamount')

# %%
table=pd.crosstab(df.Salary_Group,df.LoanAmount_Group)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Salary level vs Loan Amount Level')
plt.xlabel('Salary level')
plt.ylabel('Proportion of Loans')
#plt.legend().remove()
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Amount_Level', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Ratio_vs_loanamount')

# %%
table=pd.crosstab(df.Age_Group,df.LoanAmount_Group)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Age vs Loan Amount Dist.')
plt.xlabel('Age level')
plt.ylabel('Proportion of Loans')
plt.legend(fancybox=True, shadow=True,title = 'Loan_Amount_Level', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Age_vs_loanamount')

# %%
table=pd.crosstab(df.SP_Ratio_Group,df.LoanAmount_Group)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Liquidity Level vs Loan Amount Dist.')
plt.xlabel('Liqudity level (Salary/Payment Ratio Level)')
plt.ylabel('Proportion of Liquidity Level')
plt.legend(fancybox=True, shadow=True,title = 'Loan_Amount_Level', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Liqudity_vs_loanamount')

# %% [markdown]
# ax = plt.gca()
# leg = ax.get_legend()
# leg.legendHandles[0].set_color('red')
# leg.legendHandles[1].set_color('yellow')

# %%
table=pd.crosstab(df.Gender,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Gender vs Loan Default Status')
plt.xlabel('Gender')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('gender_vs_default_stack')

# %%
table=pd.crosstab(df.Age_Group,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Age vs Loan Default Status')
plt.xlabel('Age Group')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('age_vs_default_stack')

# %%
table=pd.crosstab(df.IsInternalRefinance,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of IsInternalRefinance vs Loan Default Status')
plt.xlabel('IsInternalRefinance')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('IsInternalRefinance_vs_default_stack')

# %%
table=pd.crosstab(df.IsExternalRefinance,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of IsExternalRefinance vs Loan Default Status')
plt.xlabel('IsExternalRefinance')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('IsExternalRefinance_vs_default_stack')

# %%
table=pd.crosstab(df.Interest,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Interest vs Loan Default Status')
plt.xlabel('Interest')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Interest_vs_default_stack')

# %%
table=pd.crosstab(df.Risky_Area,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Risky_Area vs Loan Default Status')
plt.xlabel('Risky_Area')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Risky_Area_vs_default_stack')

# %%
table=pd.crosstab(df.Month,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Month vs Loan Default Status')
plt.xlabel('Month')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Month_vs_default_stack')

# %%
table=pd.crosstab(df.V_Age_Group,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of V_Age_Group vs Loan Default Status')
plt.xlabel('V_Age_Group')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('V_Age_Group_vs_default_stack')

# %%
table=pd.crosstab(df.SP_Ratio_Group,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of SP_Ratio_Group vs Loan Default Status')
plt.xlabel('SP_Ratio_Group')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('SP_Ratio_Group_vs_default_stack')

# %%
table=pd.crosstab(df.LoanAmount_Group,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of LoanAmount_Group vs Loan Default Status')
plt.xlabel('LoanAmount_Group')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('LoanAmount_Group_vs_default_stack')

# %%
table=pd.crosstab(df.Terms,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Terms vs Loan Default Status')
plt.xlabel('Terms')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Terms_vs_default_stack')

# %%
table=pd.crosstab(df.Mileage_Group,df.Loan_Default)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Mileage_Group vs Loan Default Status')
plt.xlabel('Mileage_Group')
plt.ylabel('Proportion of Loans')
plt.axhline(1-thres, color="green")
plt.legend().set_visible(False)
# plt.legend(fancybox=True, shadow=True,title = 'Loan_Default_Status', bbox_to_anchor=(1.0, 0.9),ncol = 1)
plt.savefig('Mileage_Group_vs_default_stack')

# %%
table=pd.crosstab(df.SP_Ratio_Group,df.Age_Group, )
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of SP Ratio Level vs Age Level')
plt.xlabel('SP Ratio level')
plt.ylabel('Proportion of Age_Group')
plt.legend(fancybox=True, shadow=True,title = 'Age Level', bbox_to_anchor=(1, -0.3),ncol = 4)
plt.savefig('Ratio_vs_Age')

# %%
table=pd.crosstab(df.Interest, df.Age_Group)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of SP Ratio Level vs Age Level')
plt.xlabel('Interest Rate level')
plt.ylabel('Proportion of Age_Group')
plt.legend(fancybox=True, shadow=True,title = 'Age Level', bbox_to_anchor=(1, -0.3),ncol = 4)
plt.savefig('Ratio_vs_Age')
